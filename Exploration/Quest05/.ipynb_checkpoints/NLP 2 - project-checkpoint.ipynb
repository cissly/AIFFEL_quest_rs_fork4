# %% [markdown]
# # 프로젝트 : 네이버 영화리뷰 감성분석 도전하기

# %%
#!wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
#!wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
#!mv ratings_*.txt ~/work/project/Exploration/Quest05/nlp_project/data

#!pip install konlpy
#!git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
#%cd Mecab-ko-for-Google-Colab/
#!bash install_mecab-ko_on_colab_light_220429.sh

# %%
# !python --version
# Out:
# Python 3.12.11

# %%
#!pip install gensim==4.3.2
#!pip install scipy==1.12.0 numpy==1.26.3

# %%
import pandas
import konlpy
import gensim

print(pandas.__version__)
print(konlpy.__version__)
print(gensim.__version__)
# Out:
# 2.3.0
# 0.6.0
# 4.3.2

# %% [markdown]
# # 1. 데이터 준비와 확인

# %%
import pandas as pd

path = '~/work/project/Exploration/Quest05/nlp_project/data/'
train_data = pd.read_table(path + 'ratings_train.txt')
test_data = pd.read_table(path + 'ratings_test.txt')

train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# # 2. 데이터로더 구성
# 실습 때 다루었던 IMDB 데이터셋은 텍스트를 가공하여 imdb.data_loader() 메서드를 호출하면 숫자 인덱스로 변환된 텍스트와 word_to_index 딕셔너리까지 친절하게 제공합니다. 그러나 이번에 다루게 될 nsmc 데이터셋은 전혀 가공되지 않은 텍스트 파일로 이루어져 있습니다. 이것을 읽어서 imdb.data_loader()와 동일하게 동작하는 자신만의 data_loader를 만들어 보는 것으로 시작합니다. data_loader 안에서는 다음을 수행해야 합니다.
#
# 1. 데이터의 중복 제거
# 2. NaN 결측치 제거
# 3. 한국어 토크나이저로 토큰화
# 4. 불용어(Stopwords) 제거
# 5. 사전word_to_index 구성
# 6. 텍스트 스트링을 사전 인덱스 스트링으로 변환
# 7. X_train, y_train, X_test, y_test, word_to_index 리턴

# %%
from konlpy.tag import Mecab
import numpy as np
from collections import Counter

tokenizer = Mecab()
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

def load_data(train_data, test_data, num_words=10000):
    train_data.drop_duplicates(subset=['document'], inplace=True)
    train_data = train_data.dropna(how = 'any')
    test_data.drop_duplicates(subset=['document'], inplace=True)
    test_data = test_data.dropna(how = 'any')

    X_train = []
    for sentence in train_data['document']:
        temp_X = tokenizer.morphs(sentence) # 토큰화
        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_train.append(temp_X)

    X_test = []
    for sentence in test_data['document']:
        temp_X = tokenizer.morphs(sentence) # 토큰화
        temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
        X_test.append(temp_X)

    words = np.concatenate(X_train).tolist()
    counter = Counter(words)
    counter = counter.most_common(10000-4)
    vocab = ['', '', '', ''] + [key for key, _ in counter]
    word_to_index = {word:index for index, word in enumerate(vocab)}

    def wordlist_to_indexlist(wordlist):
        return [word_to_index[word] if word in word_to_index else word_to_index[''] for word in wordlist]

    X_train = list(map(wordlist_to_indexlist, X_train))
    X_test = list(map(wordlist_to_indexlist, X_test))

    return X_train, np.array(list(train_data['label'])), X_test, np.array(list(test_data['label'])), word_to_index

X_train, y_train, X_test, y_test, word_to_index = load_data(train_data, test_data)

# %%
index_to_word = {index:word for word, index in word_to_index.items()}
word_to_index = {k:(v) for k,v in word_to_index.items()}
word_to_index["<PAD>"] = 0
word_to_index["<BOS>"] = 1
word_to_index["<UNK>"] = 2  # unknown

# %%
# 문장 1개를 활용할 딕셔너리와 함께 주면, 단어 인덱스 리스트 벡터로 변환해 주는 함수입니다.
# 단, 모든 문장은 <BOS>로 시작하는 것으로 합니다.
def get_encoded_sentence(sentence, word_to_index):
    return [word_to_index['<BOS>']]+[word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in sentence.split()]

# 여러 개의 문장 리스트를 한꺼번에 단어 인덱스 리스트 벡터로 encode해 주는 함수입니다.
def get_encoded_sentences(sentences, word_to_index):
    return [get_encoded_sentence(sentence, word_to_index) for sentence in sentences]

# 숫자 벡터로 encode된 문장을 원래대로 decode하는 함수입니다.
def get_decoded_sentence(encoded_sentence, index_to_word):
    return ' '.join(index_to_word[index] if index in index_to_word else '<UNK>' for index in encoded_sentence[1:])  #[1:]를 통해 <BOS>를 제외

# 여러 개의 숫자 벡터로 encode된 문장을 한꺼번에 원래대로 decode하는 함수입니다.
def get_decoded_sentences(encoded_sentences, index_to_word):
    return [get_decoded_sentence(encoded_sentence, index_to_word) for encoded_sentence in encoded_sentences]

# %% [markdown]
# # 3. 모델 구성을 위한 데이터 분석 및 가공
# - 데이터셋 내 문장 길이 분포
# - 적절한 최대 문장 길이 지정
# - torch.nn.utils.rnn.pad_sequence 을 활용한 패딩 추가

# %%
def sequence_len(data):
    """
    문장길이의 평균값, 최대값, 표준편차를 계산해 본다.
    """
    num_tokens = [len(tokens) for tokens in data]
    num_tokens = np.array(num_tokens)

    sequence_mean = np.mean(num_tokens)
    sequence_max = np.max(num_tokens)
    sequence_std = np.std(num_tokens)
    
    print('문장길이 평균 : ', sequence_mean)
    print('문장길이 최대 : ', sequence_max)
    print('문장길이 표준편차 : ', sequence_std)

    max_tokens = sequence_mean + 2 * sequence_std
    maxlen = int(max_tokens)
    print(f'적정 문장 길이 : {maxlen}')
    print(f'전체 문장의 {np.sum([len(tokens) for tokens in data] < max_tokens) / len(num_tokens):.2f}%가 maxlen 설정값 이내에 포함됩니다. ')
    return sequence_mean, sequence_max, sequence_std, maxlen

# %%
sequence_mean, sequence_max, sequence_std, maxlen = sequence_len(X_train)
# Out:
# 문장길이 평균 :  15.983151140359277
# 문장길이 최대 :  116
# 문장길이 표준편차 :  12.824835920730713
# 적정 문장 길이 : 41
# 전체 문장의 0.93%가 maxlen 설정값 이내에 포함됩니다.

# %%
from torch.nn.utils.rnn import pad_sequence
import torch

X_train_maxlen = [torch.tensor(x[:maxlen]) for x in X_train]
X_test_maxlen = [torch.tensor(x[:maxlen]) for x in X_test]

x_train_padded = pad_sequence(X_train_maxlen, batch_first=True, padding_value=0, padding_side='left')
x_test_padded = pad_sequence(X_test_maxlen, batch_first=True, padding_value=0, padding_side='left')

x_train_tensor = torch.tensor(x_train_padded, dtype=torch.long)
x_test_tensor = torch.tensor(x_test_padded, dtype=torch.long)
# Out:
# /tmp/ipykernel_128/1999718855.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_train_tensor = torch.tensor(x_train_padded, dtype=torch.long)
# /tmp/ipykernel_128/1999718855.py:11: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_test_tensor = torch.tensor(x_test_padded, dtype=torch.long)

# %% [markdown]
# # 4. 모델 구성 및 validation set 구성
# - 모델은 3가지 이상 다양하게 구성하여 실험해 보세요.
# - Node 5에 존재하던 세가지 모델과 GRU를 추가로 4가지로 진행

# %%
# validation set 40000건 분리
x_val = x_train_tensor[:40000]
y_val = y_train[:40000]

# validation set을 제외한 나머지 106182 건
partial_x_train = x_train_tensor[40000:]
partial_y_train = y_train[40000:]

print(partial_x_train.shape)
print(partial_y_train.shape)

partial_x_train_tensor = torch.tensor(partial_x_train, dtype=torch.long)
partial_y_train_tensor = torch.tensor(partial_y_train, dtype=torch.float)

x_val_tensor = torch.tensor(x_val, dtype=torch.long)
y_val_tensor = torch.tensor(y_val, dtype=torch.float)

print(x_val_tensor.shape)
print(y_val_tensor.shape)
# Out:
# torch.Size([106182, 41])
# (106182,)
# torch.Size([40000, 41])
# torch.Size([40000])
# /tmp/ipykernel_128/1014078898.py:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   partial_x_train_tensor = torch.tensor(partial_x_train, dtype=torch.long)
# /tmp/ipykernel_128/1014078898.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_val_tensor = torch.tensor(x_val, dtype=torch.long)

# %%
class Model_1(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_1, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        self.lstm = nn.LSTM(word_vector_dim, 8, batch_first=True)   # 가장 널리 쓰이는 RNN인 LSTM 레이어를 사용하였습니다. 이때 LSTM state 벡터의 차원수는 8로 하였습니다. (변경 가능)
        self.fc1 = nn.Linear(8, 8)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(8, 1)    # 최종 출력은 긍정/부정
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        lstm_out, (h_n, c_n) = self.lstm(x)
        x = h_n[-1]
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
class Model_2(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_2, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        self.conv1 = nn.Conv1d(word_vector_dim, 16, kernel_size=7)
        self.conv2 = nn.Conv1d(16, 16, kernel_size=7)
        self.pool = nn.MaxPool1d(5)
        self.global_max_pooling = nn.AdaptiveMaxPool1d(1)
        self.fc1 = nn.Linear(16, 8)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(8, 1)    # 최종 출력은 긍정/부정
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(0, 2, 1)
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.global_max_pooling(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

model2 = Model_2(vocab_size, word_vector_dim)

# %%
class Model_3(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_3, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        self.global_max_pooling = nn.AdaptiveMaxPool1d(1)
        self.fc1 = nn.Linear(word_vector_dim, 8)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(8, 1)    # 최종 출력은 긍정/부정
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(0, 2, 1)
        x = self.global_max_pooling(x)
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x


model3 = Model_3(vocab_size, word_vector_dim)

# %%
class Model_4(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_4, self).__init__() 
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        
        self.gru = nn.GRU(word_vector_dim, 8, batch_first=True) 
        
        self.fc1 = nn.Linear(8, 8)
        self.fc2 = nn.Linear(8, 1)

    def forward(self, x):
        x = self.embedding(x)

        x, hn = self.gru(x) 
        

        x = x[:, -1, :] 
        x = F.relu(self.fc1(x))
        x = torch.sigmoid(self.fc2(x))
        return x

model4 = Model_4(vocab_size, word_vector_dim) 
print(model4)
# Out:
# Model_4(
#   (embedding): Embedding(10000, 100)
#   (gru): GRU(100, 8, batch_first=True)
#   (fc1): Linear(in_features=8, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

vocab_size = 10000
word_vector_dim = 100 

model1 = Model_1(vocab_size, word_vector_dim)
model2 = Model_2(vocab_size, word_vector_dim)
model3 = Model_3(vocab_size, word_vector_dim)
model4 = Model_4(vocab_size, word_vector_dim)
model_list = [model1, model2, model3, model4]

# %% [markdown]
# # 5. 모델 훈련 개시

# %%
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

loss_fn = torch.nn.BCELoss()

train_dataset = TensorDataset(partial_x_train_tensor, partial_y_train_tensor)
val_dataset = TensorDataset(x_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=512, shuffle=False)
epochs=30

def train(model_list, loss_fn, train_loader, val_loader, epochs=epochs):
    epochs = epochs
    
    # 매 epoch마다 어떻게 변하는지 알기 위한 list
    train_losses = [[] for _ in range(len(model_list))]
    val_losses = [[] for _ in range(len(model_list))]
    train_accs = [[] for _ in range(len(model_list))]
    val_accs = [[] for _ in range(len(model_list))]
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)  
    
    for i, model in enumerate(model_list):
        model.to(device)
        for module in model.modules():
            if isinstance(module, torch.nn.LSTM):
                module.flatten_parameters = lambda: None
                
        optimizer = optim.Adam(model.parameters())
        print(f"{model}")
        
        for epoch in range(epochs):
            model.train()
            running_loss = 0.0
            correct = 0
            total = 0
        
            for inputs, labels in train_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                optimizer.zero_grad()
        
                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), labels)
                loss.backward()
                optimizer.step()
        
                running_loss += loss.item()
        
                predicted = (outputs.squeeze() > 0.5).float()
                correct += (predicted == labels).sum().item()
                total += labels.size(0)
        
            train_losses[i].append(running_loss / len(train_loader))
            train_accs[i].append(correct / total)
        
            model.eval()
            val_loss = 0.0
            val_correct = 0
            val_total = 0
        
            # valid data에 대해서는 추론모드로 변경해서 진행
            with torch.no_grad():
                for inputs, labels in val_loader:
                    inputs = inputs.to(device)
                    labels = labels.to(device)
                    
                    outputs = model(inputs)
                    loss = loss_fn(outputs.squeeze(), labels)
        
                    val_loss += loss.item()
                    predicted = (outputs.squeeze() > 0.5).float()
                    val_correct += (predicted == labels).sum().item()
                    val_total += labels.size(0)
        
            val_losses[i].append(val_loss / len(val_loader))
            val_accs[i].append(val_correct / val_total)
        
            print(f"Epoch {epoch+1}/{epochs} - "
                  f"Train Loss: {train_losses[i][-1]:.4f}, Train Accuracy: {train_accs[i][-1]:.4f} - "
                  f"Validation Loss: {val_losses[i][-1]:.4f}, Validation Accuracy: {val_accs[i][-1]:.4f}")
        
        del model
        torch.cuda.empty_cache()
        print('*'*30)

    return train_losses, val_losses, train_accs, val_accs

train_losses, val_losses, train_accs, val_accs = train(model_list, loss_fn, train_loader, val_loader, epochs=30)
# Out:
# cuda
# Model_1(
#   (embedding): Embedding(10000, 100)
#   (lstm): LSTM(100, 8, batch_first=True)
#   (fc1): Linear(in_features=8, out_features=8, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=8, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1/30 - Train Loss: 0.1287, Train Accuracy: 0.9593 - Validation Loss: 0.5819, Validation Accuracy: 0.8277
# Epoch 2/30 - Train Loss: 0.1226, Train Accuracy: 0.9619 - Validation Loss: 0.5957, Validation Accuracy: 0.8275
# Epoch 3/30 - Train Loss: 0.1196, Train Accuracy: 0.9627 - Validation Loss: 0.6014, Validation Accuracy: 0.8251
# Epoch 4/30 - Train Loss: 0.1175, Train Accuracy: 0.9635 - Validation Loss: 0.6042, Validation Accuracy: 0.8256
# Epoch 5/30 - Train Loss: 0.1142, Train Accuracy: 0.9649 - Validation Loss: 0.6243, Validation Accuracy: 0.8254
# Epoch 6/30 - Train Loss: 0.1112, Train Accuracy: 0.9660 - Validation Loss: 0.6354, Validation Accuracy: 0.8260
# ...

# %%
test_dataset = TensorDataset(x_test_tensor, torch.tensor(y_test, dtype=torch.float32))
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=False)


def test_predict(model_list, test_dataset, test_loader, loss_fn):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    test_loss = [0.0, 0.0, 0.0, 0.0]
    test_correct = [0,0,0,0]
    test_total = [0,0,0,0]
    
    for i, model in enumerate(model_list):
        model.eval()
        
        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                outputs = model(inputs)
                loss = loss_fn(outputs.squeeze(), labels)
        
                test_loss[i] += loss.item()
                predicted = (outputs.squeeze() > 0.5).float()
                test_correct[i] += (predicted == labels).sum().item()
                test_total[i] += labels.size(0)
        print(f'{i+1}번째 모델')
        print(f"Test Loss: {test_loss[i] / len(test_loader):.4f}, Test Accuracy: {test_correct[i] / test_total[i]:.4f}")

test_predict(model_list, test_dataset, test_loader, loss_fn)
# Out:
# 1번째 모델
# Test Loss: 0.8663, Test Accuracy: 0.8153
# 2번째 모델
# Test Loss: 0.8023, Test Accuracy: 0.8150
# 3번째 모델
# Test Loss: 0.4856, Test Accuracy: 0.8233
# 4번째 모델
# Test Loss: 0.5484, Test Accuracy: 0.8262

# %% [markdown]
# # 6. Loss, Accuracy 그래프 시각화

# %%
import matplotlib.pyplot as plt

def Loss_Acc_Vis(model_list, train_losses, val_losses, train_accs, val_accs, epochs):
    epochs_range = range(1, epochs + 1)
    
    plt.figure(figsize=(15, 20)) 
    
    for i in range(len(model_list)):
        
        # --- Loss 그래프 (왼쪽 열) ---
        plt.subplot(4, 2, i * 2 + 1)
        
        plt.plot(epochs_range, train_losses[i], 'bo', label='Training loss')
        plt.plot(epochs_range, val_losses[i], 'b', label='Validation loss')
        
        plt.title(f'Model {i+1} - Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
    
        # --- Accuracy 그래프 (오른쪽 열) ---
        plt.subplot(4, 2, i * 2 + 2)
        
        plt.plot(epochs_range, train_accs[i], 'ro', label='Training accuracy')
        plt.plot(epochs_range, val_accs[i], 'r', label='Validation accuracy')
        
        plt.title(f'Model {i+1} - Training and Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
    
    plt.tight_layout() 
    plt.show()

Loss_Acc_Vis(model_list, train_losses, val_losses, train_accs, val_accs, epochs)

# %% [markdown]
# # 7. 학습된 Embedding 레이어 분석

# %%
from gensim.models.keyedvectors import Word2VecKeyedVectors
import os

saved_file_paths = [] 
word_vectors_list = []

# 저장할 디렉터리 경로 (없으면 생성)
save_directory = 'sentiment_classification/word2vec_emb'
os.makedirs(save_directory, exist_ok=True)

print(f"총 {len(model_list)}개의 모델 임베딩 저장을 시작합니다...")

for i, model in enumerate(model_list):
    
    print(f"\n--- Model {i+1} 처리 중 ---")
    
    # 현재 모델의 임베딩 가중치(weights)를 가져옵니다.
    vectors = model.embedding.weight.detach().cpu().numpy()
    
    current_vocab_size, word_vector_dim = vectors.shape
    
    # 파일 경로를 모델별로 다르게 지정
    word2vec_file_path = os.path.join(save_directory, f'word2vec_model_{i+1}.txt')
    saved_file_paths.append(word2vec_file_path)

    print(f"Model {i+1} 임베딩을 {word2vec_file_path} 에 저장합니다...")
    
    # Word2Vec 텍스트 포맷으로 파일 저장
    with open(word2vec_file_path, 'w') as f:
        f.write('{} {}\n'.format(current_vocab_size - 4, word_vector_dim)) 

        for j in range(4, current_vocab_size):
            word = index_to_word[j]
            vector_str = ' '.join(map(str, vectors[j, :]))
            f.write(f'{word} {vector_str}\n')

print(f"\n{'-'*30}\n모든 모델 임베딩 저장 완료.")



for file_path in saved_file_paths:
    word_vectors = Word2VecKeyedVectors.load_word2vec_format(file_path, binary=False)
    word_vectors_list.append(word_vectors)
    print(f"'{file_path}' 로드 완료.")

print(f"\n총 {len(word_vectors_list)}개의 Gensim 모델 로드 완료.")
print(word_vectors_list)
# Out:
# 총 4개의 모델 임베딩 저장을 시작합니다...
#
# --- Model 1 처리 중 ---
# Model 1 임베딩을 sentiment_classification/word2vec_emb/word2vec_model_1.txt 에 저장합니다...
#
# --- Model 2 처리 중 ---
# Model 2 임베딩을 sentiment_classification/word2vec_emb/word2vec_model_2.txt 에 저장합니다...
#
# --- Model 3 처리 중 ---
# Model 3 임베딩을 sentiment_classification/word2vec_emb/word2vec_model_3.txt 에 저장합니다...
#
# --- Model 4 처리 중 ---
# Model 4 임베딩을 sentiment_classification/word2vec_emb/word2vec_model_4.txt 에 저장합니다...
#
# ------------------------------
# 모든 모델 임베딩 저장 완료.
# Gensim으로 저장된 파일들을 불러옵니다...
# 'sentiment_classification/word2vec_emb/word2vec_model_1.txt' 로드 완료.
# 'sentiment_classification/word2vec_emb/word2vec_model_2.txt' 로드 완료.
# 'sentiment_classification/word2vec_emb/word2vec_model_3.txt' 로드 완료.
# 'sentiment_classification/word2vec_emb/word2vec_model_4.txt' 로드 완료.
#
# 총 4개의 Gensim 모델 로드 완료.
# ...

# %%
input_word = '영화'
for i,word_vectors in enumerate(word_vectors_list):
    if input_word in word_vectors:
        print(f"Model {i}에서 '{input_word}'와 유사한 단어:")
        print(word_vectors.most_similar('영화'), '\n')
# Out:
# Model 0에서 '영화'와 유사한 단어:
# [('녹음', 0.7786166667938232), ('세라', 0.7690131664276123), ('잇', 0.7624159455299377), ('빛나', 0.7483863830566406), ('소중', 0.7407564520835876), ('의료', 0.7349620461463928), ('씨네', 0.7327389121055603), ('외로움', 0.7184808254241943), ('형제', 0.7092838287353516), ('ㅎ', 0.7019755244255066)]
#
# Model 1에서 '영화'와 유사한 단어:
# [('대한', 0.8485136032104492), ('이뤄', 0.7702881097793579), ('발생', 0.7610650062561035), ('돠', 0.7523682117462158), ('나올까', 0.7402902245521545), ('취급', 0.7223615646362305), ('b', 0.7068997621536255), ('다르', 0.7059275507926941), ('주도', 0.7059139609336853), ('오덕', 0.6984078288078308)]
#
# Model 2에서 '영화'와 유사한 단어:
# [('지나치', 0.8070348501205444), ('마른', 0.7933078408241272), ('정말로', 0.7800744771957397), ('선정', 0.7784454226493835), ('거저', 0.7753128409385681), ('스크림', 0.7624989748001099), ('다며', 0.739224374294281), ('내보내', 0.7354596853256226), ('슈렉', 0.7146310210227966), ('병사', 0.7130588889122009)]
#
# Model 3에서 '영화'와 유사한 단어:
# ...

# %%
input_word = '더빙'
for i,word_vectors in enumerate(word_vectors_list):
    if input_word in word_vectors:
        print(f"Model {i}에서 '{input_word}'와 유사한 단어:")
        print(word_vectors.most_similar('영화'), '\n')
# Out:
# Model 0에서 '더빙'와 유사한 단어:
# [('녹음', 0.7786166667938232), ('세라', 0.7690131664276123), ('잇', 0.7624159455299377), ('빛나', 0.7483863830566406), ('소중', 0.7407564520835876), ('의료', 0.7349620461463928), ('씨네', 0.7327389121055603), ('외로움', 0.7184808254241943), ('형제', 0.7092838287353516), ('ㅎ', 0.7019755244255066)]
#
# Model 1에서 '더빙'와 유사한 단어:
# [('대한', 0.8485136032104492), ('이뤄', 0.7702881097793579), ('발생', 0.7610650062561035), ('돠', 0.7523682117462158), ('나올까', 0.7402902245521545), ('취급', 0.7223615646362305), ('b', 0.7068997621536255), ('다르', 0.7059275507926941), ('주도', 0.7059139609336853), ('오덕', 0.6984078288078308)]
#
# Model 2에서 '더빙'와 유사한 단어:
# [('지나치', 0.8070348501205444), ('마른', 0.7933078408241272), ('정말로', 0.7800744771957397), ('선정', 0.7784454226493835), ('거저', 0.7753128409385681), ('스크림', 0.7624989748001099), ('다며', 0.739224374294281), ('내보내', 0.7354596853256226), ('슈렉', 0.7146310210227966), ('병사', 0.7130588889122009)]
#
# Model 3에서 '더빙'와 유사한 단어:
# ...

# %% [markdown]
# # 8. 한국어 Word2Vec 임베딩 활용하여 성능 개선
# - 한국어 Word2Vec은 /data 폴더 안에 있는 word2vec_ko.model을 활용하세요.
# - 한국어 Word2Vec을 활용할 때는 load_word2vec_format() 형태가 아닌 load() 형태로 모델을 불러와주세요. 또한 모델을 활용할 때에는 아래 예시와 같이 .wv를 붙여서 활용합니다. 좀더 자세한 활용법에 대해선 다음 링크들을 참조해주세요 [참고글1](https://radimrehurek.com/gensim/auto_examples/tutorials/run_word2vec.html#storing-and-loading-models), [참고글2](https://radimrehurek.com/gensim/models/keyedvectors.html)

# %%
#!cp ~/work/sentiment_classification/data/word2vec_ko.model{,.trainables.syn1neg.npy,.wv.vectors.npy} ~/work/project/Exploration/Quest05/nlp_project/

# %%
# !pwd
# Out:
# /home/jovyan/work/project/Exploration/Quest05/Mecab-ko-for-Google-Colab

# %% [markdown]
# - 확실히 7장에서 내가 학습 모델의 임베딩으로 유사도 검색한 것과 결과가 많이 다르다는 걸 알 수가 있음
# - 학습한건 사실 전혀 다른 단어들이 뜬다.
# - 근데 아래 load한 모델은 확실히 관련된 개념들이 나온다.

# %%
from gensim.models import Word2Vec

word2vec = Word2Vec.load('/home/jovyan/work/project/Exploration/Quest05/nlp_project/word2vec_ko.model')

print(word2vec.wv.most_similar('영화'))
# Out:
# [('드라마', 0.8418774008750916), ('뮤지컬', 0.7775140404701233), ('코미디', 0.7489107251167297), ('다큐멘터리', 0.7401294708251953), ('헐리우드', 0.7397844195365906), ('애니메이션', 0.7170552015304565), ('독립영화', 0.7113528251647949), ('로맨틱', 0.7107657194137573), ('장편', 0.7101576924324036), ('극영화', 0.7045413255691528)]

# %%
gensim_vectors = word2vec.wv
pretrained_embedding_dim = gensim_vectors.vector_size

# %%
model1 = Model_1(vocab_size, pretrained_embedding_dim)
model2 = Model_2(vocab_size, pretrained_embedding_dim)
model3 = Model_3(vocab_size, pretrained_embedding_dim)
model4 = Model_4(vocab_size, pretrained_embedding_dim)
model_list = [model1, model2, model3, model4]

# %%
weights_matrix = torch.zeros((vocab_size, pretrained_embedding_dim))

found_count = 0
for word, index in word_to_index.items():
    if word in gensim_vectors:
        weights_matrix[index] = torch.tensor(gensim_vectors[word])
        found_count += 1

print(f"총 {vocab_size}개 단어 중 {found_count}개의 벡터를 사전학습 모델에서 가져왔습니다.")


for i, model in enumerate(model_list):
    try:
        # data.copy_() 를 사용해 임베딩 레이어의 가중치를 덮어씁니다.
        model.embedding.weight.data.copy_(weights_matrix)
        
        # (선택) 임베딩 레이어 동결 (학습 중 업데이트 방지)
        # model.embedding.weight.requires_grad = False 
        
        print(f"Model {i+1} ({type(model).__name__}) 임베딩 주입 완료.")
        
    except AttributeError:
        print(f"오류: Model {i+1}에 'embedding'이라는 nn.Embedding 레이어가 없습니다.")

print("---완료 ---")
# Out:
# 총 10000개 단어 중 9457개의 벡터를 사전학습 모델에서 가져왔습니다.
# Model 1 (Model_1) 임베딩 주입 완료.
# Model 2 (Model_2) 임베딩 주입 완료.
# Model 3 (Model_3) 임베딩 주입 완료.
# Model 4 (Model_4) 임베딩 주입 완료.
# ---완료 ---

# %%
train_losses, val_losses, train_accs, val_accs = train(model_list, loss_fn, train_loader, val_loader, epochs=30)
# Out:
# cuda
# Model_1(
#   (embedding): Embedding(10000, 100)
#   (lstm): LSTM(100, 8, batch_first=True)
#   (fc1): Linear(in_features=8, out_features=8, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=8, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1/30 - Train Loss: 0.6756, Train Accuracy: 0.5713 - Validation Loss: 0.6064, Validation Accuracy: 0.6942
# Epoch 2/30 - Train Loss: 0.5128, Train Accuracy: 0.7564 - Validation Loss: 0.4569, Validation Accuracy: 0.7928
# Epoch 3/30 - Train Loss: 0.4229, Train Accuracy: 0.8109 - Validation Loss: 0.4185, Validation Accuracy: 0.8148
# Epoch 4/30 - Train Loss: 0.3820, Train Accuracy: 0.8351 - Validation Loss: 0.4049, Validation Accuracy: 0.8232
# Epoch 5/30 - Train Loss: 0.3555, Train Accuracy: 0.8501 - Validation Loss: 0.3991, Validation Accuracy: 0.8263
# Epoch 6/30 - Train Loss: 0.3375, Train Accuracy: 0.8594 - Validation Loss: 0.3963, Validation Accuracy: 0.8277
# ...

# %%
test_predict(model_list, test_dataset, test_loader, loss_fn)
# Out:
# 1번째 모델
# Test Loss: 0.5115, Test Accuracy: 0.8227
# 2번째 모델
# Test Loss: 0.8386, Test Accuracy: 0.8203
# 3번째 모델
# Test Loss: 0.4331, Test Accuracy: 0.8121
# 4번째 모델
# Test Loss: 0.5167, Test Accuracy: 0.8210

# %%
Loss_Acc_Vis(model_list, train_losses, val_losses, train_accs, val_accs, epochs)

# %% [markdown]
# # 층 더 깊게 해서
# - 깊게 하다보니, epoch 돌아가는 중에 valid acc가 85%를 넘기긴 했지만
# - test는 넘기지 못했고, 사전 학습된 모델로 해도 성능이 높아지지가 않았다.
# - 중간에 코드가 제대로 주입이 안됬거나 또는 제일 위에 전처리 과정을 좀 바꿔보던가 해야겠다

# %%
class Model_1_Deeper(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_1_Deeper, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        self.lstm = nn.LSTM(word_vector_dim, 32, num_layers=3, batch_first=True, dropout=0.2) 
        
        self.fc1 = nn.Linear(32, 16) 
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5) 
        self.fc2 = nn.Linear(16, 1) 
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        lstm_out, (h_n, c_n) = self.lstm(x)
        
        x = h_n[-1] 
        
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x) 
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
class Model_2_Deeper(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_2_Deeper, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        
        self.conv1 = nn.Conv1d(word_vector_dim, 32, kernel_size=5, padding=2)
        self.bn1 = nn.BatchNorm1d(32) 
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool1d(3)
        
        self.conv2 = nn.Conv1d(32, 64, kernel_size=5, padding=2)
        self.bn2 = nn.BatchNorm1d(64)
        self.relu2 = nn.ReLU()
        self.pool2 = nn.MaxPool1d(3)
        
        self.conv3 = nn.Conv1d(64, 128, kernel_size=5, padding=2)
        self.bn3 = nn.BatchNorm1d(128)
        self.relu3 = nn.ReLU()
        self.global_max_pooling = nn.AdaptiveMaxPool1d(1)
        
        self.dropout = nn.Dropout(0.5)
        self.fc1 = nn.Linear(128, 64)
        self.relu4 = nn.ReLU() 
        self.fc2 = nn.Linear(64, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(0, 2, 1) 
        
        x = self.conv1(x)
        x = self.bn1(x) 
        x = self.relu1(x)
        x = self.pool1(x)
        
        x = self.conv2(x)
        x = self.bn2(x) 
        x = self.relu2(x)
        x = self.pool2(x)
        
        x = self.conv3(x)
        x = self.bn3(x) 
        x = self.relu3(x)
        x = self.global_max_pooling(x)
        
        x = x.view(x.size(0), -1)
        
        x = self.dropout(x)
        x = self.fc1(x)
        x = self.relu4(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x

# %%
class Model_3_Deeper(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_3_Deeper, self).__init__()
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        self.global_max_pooling = nn.AdaptiveMaxPool1d(1)
        
        self.fc1 = nn.Linear(word_vector_dim, 64) 
        self.relu1 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.5)
        
        self.fc2 = nn.Linear(64, 32)
        self.relu2 = nn.ReLU()
        self.dropout2 = nn.Dropout(0.5)
        
        self.fc3 = nn.Linear(32, 16) 
        self.relu3 = nn.ReLU()
        self.dropout3 = nn.Dropout(0.5)
        
        self.fc4 = nn.Linear(16, 1) # (이전 fc3가 fc4로 변경됨)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.embedding(x)
        x = x.permute(0, 2, 1) 
        x = self.global_max_pooling(x) 
        x = x.view(x.size(0), -1)
        

        x = self.fc1(x)
        x = self.relu1(x)
        x = self.dropout1(x)
        
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.dropout2(x)
        
        x = self.fc3(x)
        x = self.relu3(x)
        x = self.dropout3(x)
        
        x = self.fc4(x)
        x = self.sigmoid(x)
        return x

# %%
class Model_4_Bidirectional(nn.Module):
    def __init__(self, vocab_size, word_vector_dim):
        super(Model_4_Bidirectional, self).__init__() 
        self.embedding = nn.Embedding(vocab_size, word_vector_dim)
        
        hidden_size = 32 
        
        self.gru = nn.GRU(word_vector_dim, 
                          hidden_size, 
                          num_layers=3, 
                          batch_first=True, 
                          bidirectional=True,
                          dropout=0.2) 
        
        # 양방향이므로 GRU의 출력은 hidden_size * 2 가 됨
        self.fc1 = nn.Linear(hidden_size * 2, 32) 
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(32, 1) 

    def forward(self, x):
        x = self.embedding(x)
        gru_out, h_n = self.gru(x) 
        x = torch.cat((h_n[-2, :, :], h_n[-1, :, :]), dim=1) # (B, 32+32) = (B, 64)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc2(x))
        return x

# %%
vocab_size = 10000
word_vector_dim = 100 
epochs = 20

model1_deep = Model_1_Deeper(vocab_size, word_vector_dim)
model2_deep = Model_2_Deeper(vocab_size, word_vector_dim)
model3_deep = Model_3_Deeper(vocab_size, word_vector_dim)
model4_bi = Model_4_Bidirectional(vocab_size, word_vector_dim)
model_Deeper_list = [model1_deep,model2_deep,model3_deep,model4_bi]

# %%
train_losses, val_losses, train_accs, val_accs = train(model_Deeper_list, loss_fn, train_loader, val_loader, epochs)
# Out:
# cuda
# Model_1_Deeper(
#   (embedding): Embedding(10000, 100)
#   (lstm): LSTM(100, 32, num_layers=3, batch_first=True, dropout=0.2)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
# Epoch 1/20 - Train Loss: 0.5875, Train Accuracy: 0.6725 - Validation Loss: 0.4359, Validation Accuracy: 0.8036
# Epoch 2/20 - Train Loss: 0.4352, Train Accuracy: 0.7982 - Validation Loss: 0.3769, Validation Accuracy: 0.8288
# Epoch 3/20 - Train Loss: 0.3882, Train Accuracy: 0.8245 - Validation Loss: 0.3641, Validation Accuracy: 0.8398
# Epoch 4/20 - Train Loss: 0.3564, Train Accuracy: 0.8540 - Validation Loss: 0.3487, Validation Accuracy: 0.8462
# Epoch 5/20 - Train Loss: 0.3309, Train Accuracy: 0.8674 - Validation Loss: 0.3503, Validation Accuracy: 0.8478
# ...

# %%
test_predict(model_Deeper_list, test_dataset, test_loader, loss_fn)
# Out:
# 1번째 모델
# Test Loss: 0.6047, Test Accuracy: 0.8398
# 2번째 모델
# Test Loss: 0.8657, Test Accuracy: 0.8186
# 3번째 모델
# Test Loss: 0.3899, Test Accuracy: 0.8280
# 4번째 모델
# Test Loss: 0.6482, Test Accuracy: 0.8411

# %%
Loss_Acc_Vis(model_Deeper_list, train_losses, val_losses, train_accs, val_accs, epochs)
